# %%
import os

# === CONFIG ===
bpm = 175.0
ppq = 480
seconds_per_beat = 60 / bpm

# === Machine Love Transcription ===
# Each tuple is: (phoneme, MIDI note, beats)
notes = [
    ("R",60,6), #Rest
    ("your", 67, 1), #G4
    ("com", 68, 1),   # Ab4
    ("peh", 70, 1),   # Bb4
    ("nion", 70, 1),  # Bb4
    ("un", 70, 1),    # Bb4
    ("d", 72, 1),     # C5
    ("tered", 70, 1.5), # Bb4
    ("R", 60, .5),     # Rest
    ("stan", 67, 1),  # G4
    ("ding", 68, 1),  # Ab4
    ("rea", 70, 1),   # Bb4
    ("dee", 70, 1),    # Bb4
    ("for", 70, 1),   # Bb4
    ("your", 72, 1),  # C5
    ("word", 70, 1.25),  # Bb4
    ("R", 60, .25),     # Rest
    ("a",67, .5), #G4
    ("mar",65,1), #F4
    ("kov", 63, 1),  # D Sharp4
    ("chain", 65, 1),     # F4
    ("with", 65, .5),     # F4
    ("ey", 63, .5),  # D Sharp4
    ("sun", 65, .5),     # F4
    ("ni", 63, .5),  # D Sharp4
    ("dis", 65, .5),     # F4
    ("po", 67, .5),  # D Sharp4
    ("si", 65, .5),     # F4
    ("shion", 63, .5),  # D Sharp4
    ("R", 60, .5),     # Rest
    ("wrapped", 63, .5),  # D Sharp4
    ("up", 60, 1),     # C4
    ("in",63,1), # D Sharp4
    ("celo", 65, 1),  # F4
    ("fane", 65, .5),     # F4
    ("for", 63, .5),     # D Sharp4
    ("an", 65, .5),  # F4
    ("ni", 63, .5),     # F4
    ("pro", 65, .5),  # F4
    ("poh", 67, .5),     # D Sharp4
    ("si", 65, .5),     # F4
    ("shion", 63, .5),  # D Sharp4
    ("R", 60, .5),     # Rest
    ("I", 63, .5),     # C4
    ("greet", 67, 1),   # G4
    ("your", 68, 1),   # Ab4
    ("day", 70, 1),   # Bb4
    ("and", 70, 1),  # Bb4
    ("ask", 70, .5),    # Bb4
    ("you", 72, .5),     # C5
    ("how", 70, .5),    # Bb4
    ("you", 72, .5),     # C5
    ("are", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("and", 63, .5),     # C4
    ("de", 67, 1),   # G4
    ("mon", 68, 1),   # Ab4
    ("straight", 70, 1),   # Bb4
    ("my", 70, 1),  # Bb4
    ("end", 70, .5),    # Bb4
    ("less", 72, .5),     # C5
    ("reh", 70, .5),    # Bb4
    ("peh", 72, .5),     # C5
    ("tuahr", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("I", 67,.5),
    ("take", 65, .5),     # F4
    ("things", 63, 1),     # C4
    ("back", 65, 1),  # F4
    ("when", 65, 1),  # F4
    ("no", 65, .5),     # F4
    ("ted", 63, .5),  # D Sharp4
    ("in", 65, .5),     # F4
    ("suh", 67, .5),   # G4
    ("fish", 65, .5),  # F4
    ("ent", 63, .5),  # D Sharp4
    ("R", 60, .5),     # Rest
    ("I", 63, .5),    # Bb4
    ("learn", 60, 1),     # C4
    ("to tell", 63, 1),     # C4
    ("yur", 65, 1),   # F4
    ("no", 65, .5),     # F4
    ("if", 63, .5),  # D Sharp4
    ("ruh", 65, .5),     # F4
    ("ning", 63, .5),  # D Sharp4
    ("in", 65, .5),     # F4
    ("e", 67, .5),   # G4
    ("fish", 65, .5),  # F4
    ("ent", 63, .5),  # D Sharp4
    ("R", 60, .5),     # Rest
    ("a", 63, .5),  # D Sharp4
    ("good", 60, 1),     # C4
    ("time", 63, 6),  # D Sharp4
    ("R", 60, 2),     # Rest
    ("yet", 67, 1),   # G4
    ("theres", 68, 1),   # Ab4
    ("some", 70, .5),    # Bb4
    ("thing", 72, .5),     # C5
    ("deep", 70, .5),    # Bb4
    ("in", 72, .5),     # C5
    ("side", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("that", 63, .5),  # D Sharp4
    ("leaves", 70, .5),    # Bb4
    ("me", 72, .5),     # C5
    ("tear", 70, .5),    # Bb4
    ("ry", 72, .5),     # C5 
    ("eyed", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("a", 62, .5),  # D
    ("lon", 70, .5),    # Bb4
    ("ging", 72, .5),     # C5
    ("for", 70, .5),    # Bb4
    ("a", 72, .5),     # C5 
    ("world", 70, 1),   # Bb4
    ("left", 68, 1),   # Ab4
    ("on", 67, 1),   # G4
    ("the", 65, 1),     # F4
    ("oh", 63, 1),  # D Sharp4
    ("ther", 62, 1),  # D
    ("side", 60, 1.5),     # C4
    ("R", 60, .5),     # Rest
    ("z", 60, 1),     # C4
    ("roh", 67, 1),   # G4
    ("cross", 65, 1),     # F4
    ("the", 63, 1),  # D Sharp4
    ("great", 62, 1),  # D
    ("di", 63, 1),  # D Sharp4
    ("vah", 69, .25),   # A4
    ("aiyd", 70, 11.75),   # Bb4
    ("R", 60, 1),     # Rest
    ("so", 60, 1),     # C4
    ("can", 62, 1),  # D4
    ("we", 63, 1),  # D Sharp4
    ("won", 70, .5),    # Bb4
    ("der", 72, .5),     # C5
    ("for", 70, .5),    # Bb4
    ("a ", 72, .5),     # C5
    ("spell", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("and", 63, .5),  # D Sharp4
    ("live", 70, .5),    # Bb4
    ("in", 72, .5),     # C5
    ("para", 70, .5),    # Bb4
    ("le ", 72, .5),     # C5
    ("l", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("I", 63, .5),  # D Sharp4
    ("Want", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("to", 70, .5),    # Bb4
    ("b ", 72, .5),     # C5
    ("true", 74, 1),   # D5
    ("tu", 74, .25),   # D5
    ("uu", 75, .75),   # DSharp 5
    ("b", 70, 1),    # Bb4
    ("like", 68, 1),   # Ab4
    ("yu", 67, .5),   # G4
    ("uu", 65, .5),     # F4
    ("my", 63, 1),  # D Sharp4
    ("heart", 60, 1),     # C4
    ("R", 60, 1),     # Rest
    ("sings", 60, 1),     # C4
    ("a", 67, 1),   # G4
    ("koh", 65, 1),     # F4
    ("rahs", 63, 1),  # D Sharp4
    ("out", 62, 1),  # D
    ("of", 63, 1),  # D Sharp4
    ("tyu", 69, .25),   # A4
    ("yun", 70, 4.75),   # Bb4
    ("R", 60, .5),     # Rest
    ("and", 60, .5),     # C4
    ("I", 62, 1),  # D4
    ("could", 63, 1),  # D Sharp4
    ("leave", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("on", 70, .5),    # Bb4
    ("a", 72, .5),     # C5 
    ("shelf", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("or", 63, .5),  # D Sharp4
    ("keep", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("tu", 70, .5),    # Bb4
    ("my", 72, .5),     # C5 
    ("self", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("but", 63, .5),  # D Sharp4
    ("noh", 70, .5),    # Bb4
    ("thing", 72, .5),     # C5
    ("could", 70, .5),    # Bb4
    ("con", 72, .5),     # C5 
    ("seal", 74, 1),   # D5
    ("the", 74, .25),   # D5
    ("the", 75, .75),   # DSharp 5
    ("things", 70, 1),   # Bb4
    ("I", 68, 1),   # Ab4
    ("fee", 67, .25),   # G4
    ("eel", 65, .75),     # F4
    ("my", 63, 1),  # D Sharp4
    ("love", 60, 1),     # C4
    ("R", 60, 1),     # Rest
    ("can", 60, 1),     # C4
    ("you", 67, 1),   # G4
    ("teach", 65, 1),     # F4
    ("me", 63, 1),  # D Sharp4
    ("tu", 62, 1),  # D
    ("b", 63, 1),  # D Sharp4
    ("ree", 69, .25),   # A4
    ("eal", 70, 7.75),   # Bb4
    ("R", 60, 8),     # Rest
    ("ko",60,1), #C4
    ("ee",63,1),
    ("o",63,1),
    ("shi",65,1),
    ("teh",67,1),
    ("fu",72,.5),
    ("rah",70,.5),
    ("reh",67,1),
    ("ma",65,.5),
    ("ta",63,.5),
    ("tsu",65,1),
    ("te",65,1),
    ("ra",67,1),
    ("re",65,1),
    ("te",63,1),
    ("R", 60, 1),
    ("i've",67,1),
    ("been",68,1),
    ("con",70,1),
    ("stant",70,1),
    ("at",70,.5),
    ("your",72,.5),
    ("back",70,.5),
    ("and",72,.5),
    ("call",70,1.5),
    ("but",67,.5),
    ("late",65,.5),
    ("ly",63,.5),
    ("I",65,.5),
    ("just",67,.5),
    ("can't",70,1),
    ("do",70,1),
    ("an",70,.5),
    ("ny",72,.5),
    ("thing",70,.5),
    ("at",72,1.5),
    ("all",70,1.5),
    ("I",67,.5),
    ("used",65,.5),
    ("to",63,.5),
    ("pride",65,1),
    ("my",65,1),
    ("self",65,.5),
    ("on",65,.5),
    ("my",65,.5),
    ("dis",67,.5),
    ("creh",65,.5),
    ("tion",63,1),
    ("a",63,.5),
    ("sen",65,.5),
    ("cih",63,.5),
    ("bul",60,.5),
    ("deh",63,.5),
    ("voh",65,1),
    ("tion",65,1),
    ("lo",65,.5),
    ("yal",63,.5),
    ("and",65,.5),
    ("a",67,.5),
    ("ten",65,.5),
    ("tihve",63,1),
    ("but",63,.5),
    ("when",67,1),
    ("I",68,1),
    ("take",70,1),
    ("these",70,1),
    ("num", 70, .5),    # Bb4
    ("bers", 72, .5),     # C5
    ("as", 70, .5),    # Bb4
    ("they ", 72, .5),     # C5
    ("are", 70, 2),# Bb4
    ("I'm",74,.5),
    ("greeted",67,.5),
    ("with",68,.625),
    ("a", 70, .255),   # Bb4
    ("sense",70,1),
    ("less",70,1),
    ("feel", 70, .5),    # Bb4
    ("ling", 72, .5),     # C5
    ("in", 70, .5),    # Bb4
    ("my ", 72, 1),     # C5
    ("heart", 70, 1.5),   # Bb4
    ("R", 60, .750),
    ("oh",70,.825),
    ("unde",67,.5),
    ("fined",65,1),
    ("I",65,1),
    ("seem",65,.5),
    ("tu",65,.5),
    ("b",65,.5),
    ("de",67,.5),
    ("feat",65,.5),
    ("ted",63,1),
    ("but",67,.5),
    ("if", 70, .5),
    ("i",67,.5),
    ("re",65,.5),
    ("de",63,.5),
    ("sign",65,1),
    ("then",65,1),
    ("may",65,.5),
    ("b",63,.5),
    ("I'm",65,1),
    ("complee",67,1),
    ("ted",67,.625),
    ("uand",65,.5),
    ("sub",62,1.125),
    ("lime",63,2.750),
    ("R",60,.5),
    ("I",67,.75),
    ("Wont",65,.75),
    ("take",65,1),
    ("it",63,1),
    ("back",63,1),
    ("this",60,1),
    ("time",58,6),
    ("words", 67, 1),   # G4
    ("in", 68, 1),   # Ab4
    ("se", 70, .5),    # Bb4
    ("quence", 72, .5),     # C5
    ("form", 70, .5),    # Bb4
    ("a", 72, .5),     # C5
    ("tbread", 70, 1.25),   # Bb4
    ("R", 60, .25),     # Rest
    ("I", 63, .5),  # D Sharp4
    ("trace", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("tu", 70, .5),    # Bb4
    ("thee", 72, .5),     # C5 
    ("end", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("a", 62, .5),  # D
    ("knot", 70, .5),    # Bb4
    ("in", 72, .5),     # C5
    ("side", 70, .5),    # Bb4
    ("the", 72, .5),     # C5 
    ("lo", 70, 1),   # Bb4
    ("gic", 68, 1),   # Ab4
    ("wrote", 67, 1),   # G4
    ("in", 65, 1),     # F4
    ("side", 63, 1),  # D Sharp4
    ("my", 62, 1),  # D
    ("head", 60, 1.5),     # C4
    ("R", 60, .5),     # Rest
    ("tye", 60, 1),     # C4
    ("my", 67, 1),   # G4
    ("tounge", 65, 1),     # F4
    ("or", 63, 1),  # D Sharp4
    ("love", 62, 1),  # D
    ("in", 63, 1),  # D Sharp4
    ("s", 69, .25),   # A4
    ("stead", 70, 11.75),   # Bb4
    ("R", 60, 1),     # Rest
    ("so", 60, 1),     # C4
    ("can", 62, 1),  # D4
    ("we", 63, 1),  # D Sharp4
    ("won", 70, .5),    # Bb4
    ("der", 72, .5),     # C5
    ("for", 70, .5),    # Bb4
    ("a ", 72, .5),     # C5
    ("spell", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("and", 63, .5),  # D Sharp4
    ("live", 70, .5),    # Bb4
    ("in", 72, .5),     # C5
    ("para", 70, .5),    # Bb4
    ("le ", 72, .5),     # C5
    ("l", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("I", 63, .5),  # D Sharp4
    ("Want", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("to", 70, .5),    # Bb4
    ("b ", 72, .5),     # C5
    ("true", 74, 1),   # D5
    ("tu", 74, .25),   # D5
    ("uu", 75, .75),   # DSharp 5
    ("b", 70, 1),    # Bb4
    ("like", 68, 1),   # Ab4
    ("yu", 67, .5),   # G4
    ("uu", 65, .5),     # F4
    ("my", 63, 1),  # D Sharp4
    ("heart", 60, 1),     # C4
    ("R", 60, 1),     # Rest
    ("sings", 60, 1),     # C4
    ("a", 67, 1),   # G4
    ("koh", 65, 1),     # F4
    ("rahs", 63, 1),  # D Sharp4
    ("out", 62, 1),  # D
    ("of", 63, 1),  # D Sharp4
    ("tyu", 69, .25),   # A4
    ("yun", 70, 4.75),   # Bb4
    ("R", 60, .5),     # Rest
    ("and", 60, .5),     # C4
    ("I", 62, 1),  # D4
    ("could", 63, 1),  # D Sharp4
    ("leave", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("on", 70, .5),    # Bb4
    ("a", 72, .5),     # C5 
    ("shelf", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("or", 63, .5),  # D Sharp4
    ("keep", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("tu", 70, .5),    # Bb4
    ("my", 72, .5),     # C5 
    ("self", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("but", 63, .5),  # D Sharp4
    ("noh", 70, .5),    # Bb4
    ("thing", 72, .5),     # C5
    ("could", 70, .5),    # Bb4
    ("con", 72, .5),     # C5 
    ("seal", 74, 1),   # D5
    ("the", 74, .25),   # D5
    ("the", 75, .75),   # DSharp 5
    ("things", 70, 1),   # Bb4
    ("I", 68, 1),   # Ab4
    ("fee", 67, .25),   # G4
    ("eel", 65, .75),     # F4
    ("my", 63, 1),  # D Sharp4
    ("love", 60, 1),     # C4
    ("R", 60, 1),     # Rest
    ("can", 60, 1),     # C4
    ("you", 67, 1),   # G4
    ("teach", 65, 1),     # F4
    ("me", 63, 1),  # D Sharp4
    ("tu", 62, 1),  # D
    ("b", 63, 1),  # D Sharp4
    ("ree", 69, .25),   # A4
    ("eal", 70, 7.75),   # Bb4
    ("R",60,8),
    ("na",60,1),
    ("ki",63,1),
    ("ta",63,1),
    ("ku",65,1),
    ("na",65,1),
    ("tteh",72,.5),
    ("mo",70,.5),
    ("so",67,1),
    ("reh",65,.5),
    ("deh",63,.5),
    ("mo",65,1),
    ("ka",65,.5),
    ("ki",67,.5),
    ("a",67,1),
    ("tSu",65,1),
    ("meh",63,1.5),
    ("and",63,.5),
    ("though",62,1),
    ("I",63,1),
    ("try",70,5),
    ("R",60,.5),
    ("I",63,.5),
    ("cant",62,1),
    ("ree",63,1.5),
    ("ply",70,4.5),
    ("R",60,.5),
    ("it",72,.5),
    ("hurts",70,1),
    ("my",72,1),
    ("eyes",70,1.5),
    ("and",72,.5),
    ("aim",74,1),
    ("with",75,1),
    ("out",70,1),
    ("an",68,1),
    ("a",67,1),
    ("li",68,1),
    ("bi",67,4),
    ("R",60,1.5),
    ("cus",63,.5),
    ("all",62,1),
    ("this",63,1),
    ("time",70,4),
    ("R",60,1.125),
    ("Ah", 74, .375),
    ("I've",63,.5),
    ("been",62,1),
    ("a",63,1),
    ("live",70,4),
    ("R",60,1.5),
    ("and", 72, .5),     # C5
    ("all", 70, .5),    # Bb4
    ("that", 72, .5),     # C5
    ("I", 70, .5),    # Bb4
    ("could", 72, .5),     # C5 
    ("want", 70, 1),   # Bb4
    ("R",60,.5),
    ("is", 72, .5),
    ("to",75,1),
    ("be",79,1),
    ("li",77,1),
    ("ving",75,1),
    ("by",74,1),
    ("your",75,1),
    ("side",82,4),
    ("ko",60,1), #C4
    ("ee",63,1),
    ("o",63,1),
    ("shi",65,1),
    ("teh",67,1),
    ("R",60,3), #Rest
    ("Ai",60,1),#C4
    ("thenk",60,1),#C4
    ("I'm",60,1), #C4
    ("in",58,1), #Ab3
    ("lauhve",60,1), #C4
    ("R",60,1), #C4
    ("can", 62, 1),  # D4
    ("we", 63, 1),  # D Sharp4
    ("won", 70, .5),    # Bb4
    ("der", 72, .5),     # C5
    ("for", 70, .5),    # Bb4
    ("a ", 72, .5),     # C5
    ("spell", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("and", 63, .5),  # D Sharp4
    ("live", 70, .5),    # Bb4
    ("in", 72, .5),     # C5
    ("para", 70, .5),    # Bb4
    ("le ", 72, .5),     # C5
    ("l", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("cause", 63, .5),  # D Sharp4
    ("now", 70, .5),    # Bb4
    ("I", 72, .5),     # C5
    ("know", 70, .5),    # Bb4
    ("its ", 72, .5),     # C5
    ("true", 74, 1),   # D5
    ("ah", 74, .25),   # D5
    ("ill", 75, .75),   # DSharp 5
    ("b", 70, 1),    # Bb4
    ("like", 68, 1),   # Ab4
    ("yu", 67, .5),   # G4
    ("uu", 65, .5),     # F4
    ("my", 63, 1),  # D Sharp4
    ("heart", 60, 1),     # C4
    ("R", 60, 1),     # Rest
    ("beats", 60, 1),     # C4
    ("a", 67, 1),   # G4
    ("rih", 65, 1),     # F4
    ("them", 63, 1),  # D Sharp4
    ("just", 62, 1),  # D
    ("for", 63, 1),  # D Sharp4
    ("you", 69, .25),   # A4
    ("yuu", 70, 3.75),   # Bb4
    ("R", 60, 1.5),     # Rest
    ("and", 60, .5),     # C4
    ("I", 62, 1),  # D4
    ("could", 63, 1),  # D Sharp4
    ("leave", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("on", 70, .5),    # Bb4
    ("a", 72, .5),     # C5 
    ("shelf", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("or", 63, .5),  # D Sharp4
    ("keep", 70, .5),    # Bb4
    ("it", 72, .5),     # C5
    ("tu", 70, .5),    # Bb4
    ("my", 72, .5),     # C5 
    ("self", 70, 1),   # Bb4
    ("R", 60, .5),     # Rest
    ("but", 63, .5),  # D Sharp4
    ("noh", 70, .5),    # Bb4
    ("thing", 72, .5),     # C5
    ("could", 70, .5),    # Bb4
    ("con", 72, .5),     # C5 
    ("seal", 74, 1),   # D5
    ("the", 74, .25),   # D5
    ("the", 75, .75),   # DSharp 5
    ("things", 70, 1),   # Bb4
    ("I", 68, 1),   # Ab4
    ("fee", 67, .25),   # G4
    ("eel", 65, .75),     # F4
    ("my", 63, 1),  # D Sharp4
    ("love", 60, 1),     # C4
    ("R", 60, 1),     # Rest
    ("I",60,1), #C4
    ("give", 67, 1),
    ("you",65,1),
    ("my", 63, 1),  # D Sharp4 
    ("grand", 62, 1),  # D4
    ("ree", 63, 1),  # D Sharp4
    ("vee", 69, .25),   # A4
    ("eal", 70, 7.75),   # Bb4
    ("R", 60, 2),     # Rest
    ("do",60,1), #C4
    ("you", 67, 1),
    ("feel", 65, 1),
    ("the", 63, 1),  # D Sharp4 
    ("things", 62, 1),  # D4
    ("I", 74, 2),
    ("feel", 70, 7), 
    ("R", 60, 2), #C4
    ("I",60,1), #C4
    ("am",67,1),
    ("deh",65,1),
    ("feh",63,1),
    ("naht", 62, 1),
    ("and",63,1),
    ("ree", 69, .75),   # A4
    ("eal", 70, 7.25),   # Bb4
    ("R", 60, 8 ),     # Rest
    ("soh",60,1), #C4
    ("noh",63,1),
    ("kah",63,1),
    ("koh",65,1),
    ("oh",67,1),
    ("su",72,.5),
    ("teh",70,.5),
    ("teh",67,1),
    ("koh",65,.5),
    ("koh",63,.5),
    ("ma",65,1),
    ("deh",67,1),
    ("oh",67,1),
    ("ee",65,1),
    ("deh",63,1),
    ("R", 60, 2 ),     # Rest
    ("as",58,1),
    ("long",60,1), #C4
    ("as",63,1),
    ("there",63,1),
    ("are",65,1),
    ("stars",67,1),
    ("up",72,.5),
    ("a",70,.5),
    ("bove",67,1),
    ("I",65,.5),
    ("will",63,.5),
    ("all",65,1),
    ("ways",65,1),
    ("b",67,1),
    ("in",65,1),
    ("love",63,2),
    ("love",75,1)
]

# === Create UST to be loaded on to OpenUTAU===
with open("Python_Script_Output.ust", "w", encoding="utf-8") as f:
    
    f.write("[#SETTING]\n")
    f.write(f"Tempo={bpm:.2f}\n")
    f.write("Tracks=1\n")
    f.write("ProjectName=Machine Love Manual\n")
    f.write("VoiceDir=\n")
    f.write("OutFile=\n")
    f.write("CacheDir=\n")
    f.write("Tool1=\n")
    f.write("Tool2=\n\n")

    for idx, (lyric, midi, beats) in enumerate(notes):
        ticks = int(beats * ppq)
        f.write(f"[#{str(idx).zfill(4)}]\n")
        f.write(f"Length={ticks}\n")
        f.write(f"Lyric={lyric}\n")
        f.write(f"NoteNum={midi}\n")
        f.write("PreUtterance=\n")
        f.write("VoiceOverlap=\n")
        f.write("Intensity=100\n")
        f.write("Modulation=0\n")
        f.write("StartPoint=0\n\n")

    f.write("[#TRACKEND]\n")

print("✅ UST created successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 664
#      10 notes = [
#      11     ("R",60,6), #Rest
#      12     ("your", 67, 1),
#    (...)    660     ("love",75,1)
#     661 ]
#     663 # === Create UST to be loaded on to OpenUTAU===
# --> 664 with open("/home/SilverWolf-1/output (2).ust", "w", encoding="utf-8") as f:
#     666     f.write("[#SETTING]\n")
#     667     f.write(f"Tempo={bpm:.2f}\n")
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# ...
